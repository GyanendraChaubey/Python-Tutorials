# %% [markdown]
# <a href="https://colab.research.google.com/github/GyanendraChaubey/Python-Tutorials/blob/main/Session%208%20HCL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Printing methods in Python

# %%
a=5
b=6
print(a,b)
# Out:
# 5 6

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("The value of a:",a,"The value of b:",b)
# Out:
# The value of a: 5 The value of b: 6

# %%
print("The value of a: %.2f" %a)
# Out:
# The value of a: 5.00

# %%
print("Continue on the",end=" ")
print("same line", end="\n")
print("next line")
# Out:
# Continue on the same line
# next line

# %%
print("a is",a,"b is",b,".")
# Out:
# a is 5 b is 6 .

# %%
print("a is",a,"b is",b,".",sep="")
# Out:
# a is  5  b is  6  .

# %% [markdown]
# Reading or writing file from disk

# %%
op=open('/content/drive/MyDrive/1475587161302.jpg')

# %%
op
# Out:
# <_io.TextIOWrapper name='/content/drive/MyDrive/1475587161302.jpg' mode='r' encoding='UTF-8'>

# %%
image=op.read()
image
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-9318a9bece53> in <module>()
# ----> 1 image=op.read()
#       2 image
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
fh=open("/content/drive/MyDrive/Rec.csv",'r')

# %%
contents=fh.read()

# %%
contents
# Out:
# 'pkSeqID,proto,saddr,sport,daddr,dport,seq,stddev,N_IN_Conn_P_SrcIP,min,state_number,mean,N_IN_Conn_P_DstIP,drate,srate,max,attack,category,subcategory\n3591126,tcp,192.168.100.150,45115,192.168.100.7,3031,13913,0,100,0.000423,1,0.000423,100,0,0,0.000423,1,Reconnaissance,OS_Fingerprint\n3664695,tcp,192.168.100.150,61890,192.168.100.5,9502,5431,0,98,0.000781,1,0.000781,100,0,0,0.000781,1,Reconnaissance,Service_Scan\n3626816,tcp,192.168.100.147,1822,192.168.100.3,916,3030,0,100,0.004917,1,0.004917,100,406.752075,203.376038,0.004917,1,Reconnaissance,Service_Scan\n3664169,tcp,192.168.100.149,33626,192.168.100.5,9000,4900,0,100,0.002834,1,0.002834,100,0,0,0.002834,1,Reconnaissance,Service_Scan\n3630606,tcp,192.168.100.149,1216,192.168.100.3,400,6924,0,100,0.005377,1,0.005377,100,185.97731,185.97731,0.005377,1,Reconnaissance,Service_Scan\n3643512,tcp,192.168.100.150,49328,192.168.100.3,49152,20196,0,100,4.20E-05,1,4.20E-05,100,0,0,4.20E-05,1,Reconnaissance,Service_Scan\n3639738,udp,192.168
# ...

# %%
contents1=fh.readline()

# %%
contents1
# Out:
# ''

# %%
op1=open('/content/drive/MyDrive/srs_template-ieee.doc','r')

# %%
content2=op1.read()

# %%
content2
# Out:
# 'My name is Gyanendra'

# %%
op1=open('/content/drive/MyDrive/srs_template-ieee.doc','w')

# %%
op1.write("My name is Gyanendra")
# Out:
# 20

# %%
op1=open('/content/drive/MyDrive/srs_template-ieee.doc','r')

# %%
textlist=["My name is Gyanendra.\n","I am living in Lucknow"]
op1.writelines(textlist)

# %%
op1=open('/content/drive/MyDrive/srs_template-ieee.doc','r')

# %%
content2=op1.read()
content2
# Out:
# ''

# %%
myfile=open('/content/drive/MyDrive/srs_template-ieee.doc','w')

# %%
textlist=["My name is Gyanendra\n","I am living in Lucknow"]
myfile.writelines(textlist)

# %%
myfile=open('/content/drive/MyDrive/srs_template-ieee.doc')
con=myfile.read()
con
# Out:
# 'My name is Gyanendra\nI am living in Lucknow'

# %%
myfile.close()

# %%
op1.flush()

# %%
op1.close()
